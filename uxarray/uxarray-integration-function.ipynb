# %% [markdown]
# # Integration Function Testing

# %%
# import uxarray for I/O purposes
import uxarray as ux
import numpy as np

# %%
# Import data for integration
uds = ux.open_dataset("./data/outCSne30.ug", "./data/outCSne30_vortex.nc", "./data/outCSne30_var2.ug")
# Out:
# Loading initial grid from file:  ./data/outCSne30.ug

# %%
uds

# %% [markdown]
# ## Using Original Integrate Function

# %%
# %prun uds.integrate("psi")
# Out:
#          47114453 function calls (45466679 primitive calls) in 62.676 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    388800   14.531    0.000   43.960    0.000 helpers.py:169(calculate_spherical_triangle_jacobian)
#    388800    9.234    0.000   26.724    0.000 numeric.py:1479(cross)
#   1166400    4.735    0.000   14.267    0.000 numeric.py:1404(moveaxis)
#   2332800    4.719    0.000    7.191    0.000 numeric.py:1341(normalize_axis_tuple)
#     27008    2.250    0.000    2.250    0.000 {method 'acquire' of '_thread.lock' objects}
#   2376000    2.021    0.000    2.021    0.000 {built-in method numpy.array}
# 1620001/421201    1.455    0.000   27.642    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     97202    1.232    0.000    2.242    0.000 dataset.py:1389(_construct_dataarray)
#      5400    1.155    0.000   46.428    0.009 helpers.py:123(calculate_face_area)
# ...

# %% [markdown]
# ## v_integrate branch

# %%
# %prun uds.integrate("psi")
# Out:
#          47049815 function calls (45402038 primitive calls) in 62.420 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    388800   14.364    0.000   43.665    0.000 helpers.py:169(calculate_spherical_triangle_jacobian)
#    388800    9.033    0.000   26.532    0.000 numeric.py:1479(cross)
#   1166400    4.760    0.000   14.264    0.000 numeric.py:1404(moveaxis)
#   2332800    4.681    0.000    7.147    0.000 numeric.py:1341(normalize_axis_tuple)
#     27008    2.270    0.000    2.270    0.000 {method 'acquire' of '_thread.lock' objects}
#   2376000    2.095    0.000    2.095    0.000 {built-in method numpy.array}
# 1620001/421201    1.478    0.000   27.477    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     97205    1.241    0.000    2.273    0.000 dataset.py:1389(_construct_dataarray)
#      5400    1.151    0.000   46.108    0.009 helpers.py:123(calculate_face_area)
# ...
