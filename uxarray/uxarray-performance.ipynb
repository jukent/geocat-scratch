# %% [markdown]
# # UXARRAY Performance Testing

# %% [markdown]
# ## Large File IO

# %%
import uxarray as ux

# %% [markdown]
# from ncar_jobqueue import NCARCluster
# import dask.distributed as dd
# import dask.array as da
# import xarray as xr

# %% [markdown]
# ## Create and Connect to Dask Cluster

# %%
cluster = NCARCluster()
cluster.scale(jobs=5)
client = dd.Client(cluster)
# Out:
# /glade/work/anissaz/miniconda3/envs/geocat-testing/lib/python3.10/site-packages/distributed/node.py:177: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43665 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'tcp://10.12.206.46:34394' processes=5 threads=10, memory=232.85 GiB>

# %% [markdown]
# ## Pull data from internal file
# Look at internal source, `diag.2016-08-01_00.00.00.nc`

# %%
# !ls -l /glade/p/cisl/vast/vapor/data/Source/MPAS/FalkoJudt/3.75km --block-size=1G
# Out:
# total 75
# -rw-r--r-- 1 clyne vapor 15 May 21  2019 diag.2016-08-01_00.00.00.nc
# -rw-rw-r-- 1 clyne vapor 60 May 21  2019 x1.static.nc

# %%
# set filepath
datapath = '/glade/p/cisl/vast/vapor/data/Source/MPAS/FalkoJudt/3.75km/diag.2016-08-01_00.00.00.nc'

# pull with xarray
ds_xarray = xr.open_dataset(datapath)

# %%
ds_xarray
# Out:
# <xarray.Dataset>
# Dimensions:             (Time: 1, nCells: 41943042, nVertices: 83886080)
# Dimensions without coordinates: Time, nCells, nVertices
# Data variables: (12/89)
#     xtime               (Time) |S64 b'2016-08-01_00:00:00                    ...
#     taux                (Time, nCells) float32 ...
#     tauy                (Time, nCells) float32 ...
#     olrtoa              (Time, nCells) float32 ...
#     cldcvr              (Time, nCells) float32 ...
#     vert_int_qv         (Time, nCells) float32 ...
#     ...                  ...
#     aclwnetb            (Time, nCells) float32 ...
#     aclwupt             (Time, nCells) float32 ...
#     aclwdnt             (Time, nCells) float32 ...
#     aclwnett            (Time, nCells) float32 ...
#     rainc               (Time, nCells) float32 ...
#     rainnc              (Time, nCells) float32 ...
# Attributes: (12/112)
#     model_name:                        mpas
#     core_name:                         atmosphere
# ...

# %%
# pull with uxarray
ux.Grid(datapath)
# Out:
# This is not a supported NetCDF file
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # pull with uxarray
# ----> 2 ux.Grid(datapath)
#
# File /glade/work/anissaz/miniconda3/envs/geocat-testing/lib/python3.10/site-packages/uxarray/grid.py:92, in Grid.__init__(self, *args, **kwargs)
#      90     self.filepath = data_arg
#      91     # call the appropriate reader
# ---> 92     self.__from_file__()
#      94 # check if invalid initialization
#      95 else:
#      96     raise RuntimeError(data_arg + " is not a valid input type")
#
# File /glade/work/anissaz/miniconda3/envs/geocat-testing/lib/python3.10/site-packages/uxarray/grid.py:145, in Grid.__from_file__(self)
#     137 """Loads a mesh file Also, called by __init__ routine This routine will
#     138 automatically detect if it is a UGrid, SCRIP, Exodus, or shape file.
#     139
# ...

# %%
client.shutdown()

# %%
client
# Out:
# <Client: 'tcp://10.12.206.46:34394' processes=5 threads=10, memory=232.85 GiB>
